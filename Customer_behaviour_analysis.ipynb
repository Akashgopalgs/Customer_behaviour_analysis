# %%
import pandas as pd
import numpy as numpy
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv('/content/ecommerce_customer_data.csv')
df
# Out:
#      User_ID  Gender  Age   Location Device_Type  Product_Browsing_Time  \
# 0          1  Female   23  Ahmedabad      Mobile                     60
# 1          2    Male   25    Kolkata      Tablet                     30
# 2          3    Male   32  Bangalore     Desktop                     37
# 3          4    Male   35      Delhi      Mobile                      7
# 4          5    Male   27  Bangalore      Tablet                     35
# ..       ...     ...  ...        ...         ...                    ...
# 495      496    Male   24     Mumbai      Tablet                     40
# 496      497  Female   24  Hyderabad     Desktop                      8
# 497      498    Male   19       Pune     Desktop                     33
# 498      499    Male   28    Chennai     Desktop                      6
# 499      500  Female   31    Kolkata      Mobile                     16
#
#      Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   User_ID                500 non-null    int64
#  1   Gender                 500 non-null    object
#  2   Age                    500 non-null    int64
#  3   Location               500 non-null    object
#  4   Device_Type            500 non-null    object
#  5   Product_Browsing_Time  500 non-null    int64
#  6   Total_Pages_Viewed     500 non-null    int64
#  7   Items_Added_to_Cart    500 non-null    int64
#  8   Total_Purchases        500 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 35.3+ KB

# %%
df.describe()
# Out:
#           User_ID         Age  Product_Browsing_Time  Total_Pages_Viewed  \
# count  500.000000  500.000000             500.000000          500.000000
# mean   250.500000   26.276000              30.740000           27.182000
# std    144.481833    5.114699              15.934246           13.071596
# min      1.000000   18.000000               5.000000            5.000000
# 25%    125.750000   22.000000              16.000000           16.000000
# 50%    250.500000   26.000000              31.000000           27.000000
# 75%    375.250000   31.000000              44.000000           38.000000
# max    500.000000   35.000000              60.000000           50.000000
#
#        Items_Added_to_Cart  Total_Purchases
# count           500.000000       500.000000
# mean              5.150000         2.464000
# std               3.203127         1.740909
# min               0.000000         0.000000
# 25%               2.000000         1.000000
# ...

# %%
sa=px.bar(df,x='Gender',y='Total_Purchases')
sa.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the above plot it's clear that Males purchased more than females

# %%
df['User_ID'].drop_duplicates().count()
# Out:
# 500

# %%
aa=df.groupby('Device_Type')
aa.sum()
# Out:
# <ipython-input-24-970fa56405c8>:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#              User_ID   Age  Product_Browsing_Time  Total_Pages_Viewed  \
# Device_Type
# Desktop        41316  4168                   4743                4134
# Mobile         42823  4750                   5459                4947
# Tablet         41111  4220                   5168                4510
#
#              Items_Added_to_Cart  Total_Purchases
# Device_Type
# Desktop                      741              381
# Mobile                      1007              451
# Tablet                       827              400

# %% [markdown]
# people only purchase roughly half of the items they initially add to their shopping carts.

# %%
px.bar(df,x='Device_Type',y='Total_Purchases')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.barplot(data=df,x='Device_Type',y='Items_Added_to_Cart')
# Out:
# <Axes: xlabel='Device_Type', ylabel='Items_Added_to_Cart'>

# %% [markdown]
# From the above plots and results shows that the customer's total purchase,items_added_to_cart and the product browsing time are higher when the customer using mobile

# %%
a=df.groupby('Location')
a.sum()
# Out:
# <ipython-input-28-ffb04b0d42ab>:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#            User_ID   Age  Product_Browsing_Time  Total_Pages_Viewed  \
# Location
# Ahmedabad    15359  1679                   1843                1670
# Bangalore    15013  1616                   1985                1658
# Chennai      14209  1431                   1520                1602
# Delhi        16616  1804                   2056                1879
# Hyderabad    16384  1596                   2066                1601
# Kolkata      16827  1901                   2374                1981
# Mumbai       15119  1541                   1795                1594
# Pune         15723  1570                   1731                1606
#
#            Items_Added_to_Cart  Total_Purchases
# Location
# ...

# %%
px.histogram(df,x='Location',y='Total_Purchases')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df,x='Location',y='Product_Browsing_Time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The above plot shows most total purchases from delhi and most product browsing time from kolkata.

# %%
b=df.groupby('Gender')
b.sum()
# Out:
# <ipython-input-47-48a6c00dc69d>:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#         User_ID   Age  Product_Browsing_Time  Total_Pages_Viewed  \
# Gender
# Female    59081  6277                   7540                6591
# Male      66169  6861                   7830                7000
#
#         Items_Added_to_Cart  Total_Purchases
# Gender
# Female                 1260              544
# Male                   1315              688

# %%
px.histogram(df,x='Gender',y='Product_Browsing_Time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df,x='Gender',y='Total_Purchases')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Male have higher purchasing rate and product browsing time when compared to females

# %%
px.histogram(df,x='Age',y='Product_Browsing_Time',color='Gender',nbins=18)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df,x='Age',y='Total_Purchases',color='Gender',nbins=18)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The women who have spent the most time browsing are in the age group of 18, whereas men are from the age group of 29. And women highest purchasing rate are in the age group of 18, whereas men are from the age group of 18,21 and 22

# %% [markdown]
# From the given dataset Male has purchased more than female.Customers purchased product from mobile than any other devises.Most products had delivered to delhi and most product browsed from kolkata.18 year old women purchased and browsed more than other women.men higher purchasing at the age group of 18,21,22.male have higher purchasing and browsing time than female
#
# > Indented block
